# %% [markdown]
# <a href="https://colab.research.google.com/github/ColeLeal/NFL_Data_Scrape/blob/main/Nfl_dataScrape_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import urllib.request
import csv

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Make a list of the title of each row that we want

df_Cols = ['team_name','season_year','game_date','game_outcome','team_record','opponent','pts_off',
            'pts_def','first_down_off','yards_off','pass_yds_off','rush_yds_off','to_off',
            'first_down_def','yards_def','pass_yds_def','rush_yds_def','to_def']
#gameData = df_Cols

# %%
# Specify starting url
urlpage1 = 'https://www.pro-football-reference.com/years/2010/games.htm'

# %%
# Request main page of interest
from urllib.request import Request, urlopen
req = Request(urlpage1, headers = {'User-Agent': 'XYZ/3.0'})
webpage1 = urlopen(req).read()

soup = BeautifulSoup(webpage1, 'html.parser')


seasonGameExts = []
# For each season page we get every teams link ext (for that season) and add the ext to an array
for i in range(11):
  # Link to each seasons page
  if i > 0:
    # Get next season link extension 
    seasonResult = soup.find('div',attrs={'class': 'prevnext'}).find('a',attrs={'class':'button2 next'}).get('href')
    seasonRequest = Request('https://www.pro-football-reference.com'+seasonResult)
    seasonPage = urlopen(seasonRequest).read()
    soup = BeautifulSoup(seasonPage, 'html.parser')

  # Get each winners table cell and each losers data cell for the whole year
  gameResultsW = soup.find_all('td', attrs={'data-stat' : 'winner'})
  gameResultsL = soup.find_all('td', attrs={'data-stat': 'loser'})

  # Append each secondary link from the first 16 (wk1) games of the season
  # This will contain link extensions to every team for that season
  for i in range(16):
    seasonGameExts.append(gameResultsW[i].find('a').get('href'))
    seasonGameExts.append(gameResultsL[i].find('a').get('href'))
  print(len(seasonGameExts))
  print('loop number:',i)

seasonGameExts
# Out:
# 32
# loop number: 15
# 64
# loop number: 15
# 96
# loop number: 15
# 128
# loop number: 15
# 160
# loop number: 15
# 192
# loop number: 15
# 224
# loop number: 15
# 256
# loop number: 15
# 288
# loop number: 15
# 320
# loop number: 15
# 352
# loop number: 15
# ['/teams/nor/2010.htm',
#  '/teams/min/2010.htm',
#  '/teams/pit/2010.htm',
#  '/teams/atl/2010.htm',
#  '/teams/oti/2010.htm',
#  '/teams/rai/2010.htm',
#  '/teams/tam/2010.htm',
#  '/teams/cle/2010.htm',
#  '/teams/mia/2010.htm',
#  '/teams/buf/2010.htm',
#  '/teams/chi/2010.htm',
#  '/teams/det/2010.htm',
#  '/teams/nwe/2010.htm',
#  '/teams/cin/2010.htm',
#  '/teams/htx/2010.htm',
#  '/teams/clt/2010.htm',
#  '/teams/jax/2010.htm',
#  '/teams/den/2010.htm',
#  '/teams/nyg/2010.htm',
#  '/teams/car/2010.htm',
#  '/teams/crd/2010.htm',
#  '/teams/ram/2010.htm',
#  '/teams/gnb/2010.htm',
#  '/teams/phi/2010.htm',
#  '/teams/sea/2010.htm',
#  '/teams/sfo/2010.htm',
#  '/teams/was/2010.htm',
#  '/teams/dal/2010.htm',
#  '/teams/rav/2010.htm',
#  '/teams/nyj/2010.htm',
#  '/teams/kan/2010.htm',
#  '/teams/sdg/2010.htm',
#  '/teams/gnb/2011.htm',
#  '/teams/nor/2011.htm',
#  '/teams/phi/2011.htm',
#  '/teams/ram/2011.htm',
#  '/teams/rav/2011.htm',
#  '/teams/pit/2011.htm',
#  '/teams/jax/2011.htm',
#  '/teams/oti/2011.htm',
#  '/teams/htx/2011.htm',
#  '/teams/clt/2011.htm',
#  '/teams/chi/2011.htm',
#  '/teams/atl/2011.htm',
#  '/teams/buf/2011.htm',
#  '/teams/kan/2011.htm',
#  '/teams/det/2011.htm',
#  '/teams/tam/2011.htm',
#  '/teams/cin/2011.htm',
#  '/teams/cle/2011.htm',
#  '/teams/crd/2011.htm',
#  '/teams/car/2011.htm',
#  '/teams/sdg/2011.htm',
#  '/teams/min/2011.htm',
#  '/teams/sfo/2011.htm',
#  '/teams/sea/2011.htm',
#  '/teams/was/2011.htm',
#  '/teams/nyg/2011.htm',
#  '/teams/nyj/2011.htm',
#  '/teams/dal/2011.htm',
#  '/teams/nwe/2011.htm',
#  '/teams/mia/2011.htm',
#  '/teams/rai/2011.htm',
#  '/teams/den/2011.htm',
#  '/teams/dal/2012.htm',
#  '/teams/nyg/2012.htm',
#  '/teams/chi/2012.htm',
#  '/teams/clt/2012.htm',
#  '/teams/atl/2012.htm',
#  '/teams/kan/2012.htm',
#  '/teams/nyj/2012.htm',
#  '/teams/buf/2012.htm',
#  '/teams/det/2012.htm',
#  '/teams/ram/2012.htm',
#  '/teams/phi/2012.htm',
#  '/teams/cle/2012.htm',
#  '/teams/was/2012.htm',
#  '/teams/nor/2012.htm',
#  '/teams/nwe/2012.htm',
#  '/teams/oti/2012.htm',
#  '/teams/htx/2012.htm',
#  '/teams/mia/2012.htm',
#  '/teams/min/2012.htm',
#  '/teams/jax/2012.htm',
#  '/teams/crd/2012.htm',
#  '/teams/sea/2012.htm',
#  '/teams/sfo/2012.htm',
#  '/teams/gnb/2012.htm',
#  '/teams/tam/2012.htm',
#  '/teams/car/2012.htm',
#  '/teams/den/2012.htm',
#  '/teams/pit/2012.htm',
#  '/teams/rav/2012.htm',
#  '/teams/cin/2012.htm',
#  '/teams/sdg/2012.htm',
#  '/teams/rai/2012.htm',
#  '/teams/den/2013.htm',
#  '/teams/rav/2013.htm',
#  '/teams/nwe/2013.htm',
#  '/teams/buf/2013.htm',
#  '/teams/oti/2013.htm',
#  '/teams/pit/2013.htm',
#  '/teams/det/2013.htm',
#  '/teams/min/2013.htm',
#  '/teams/mia/2013.htm',
#  '/teams/cle/2013.htm',
#  '/teams/clt/2013.htm',
#  '/teams/rai/2013.htm',
#  '/teams/chi/2013.htm',
#  '/teams/cin/2013.htm',
#  '/teams/nor/2013.htm',
#  '/teams/atl/2013.htm',
#  '/teams/nyj/2013.htm',
#  '/teams/tam/2013.htm',
#  '/teams/kan/2013.htm',
#  '/teams/jax/2013.htm',
#  '/teams/sea/2013.htm',
#  '/teams/car/2013.htm',
#  '/teams/ram/2013.htm',
#  '/teams/crd/2013.htm',
#  '/teams/sfo/2013.htm',
#  '/teams/gnb/2013.htm',
#  '/teams/dal/2013.htm',
#  '/teams/nyg/2013.htm',
#  '/teams/phi/2013.htm',
#  '/teams/was/2013.htm',
#  '/teams/htx/2013.htm',
#  '/teams/sdg/2013.htm',
#  '/teams/sea/2014.htm',
#  '/teams/gnb/2014.htm',
#  '/teams/buf/2014.htm',
#  '/teams/chi/2014.htm',
#  '/teams/min/2014.htm',
#  '/teams/ram/2014.htm',
#  '/teams/pit/2014.htm',
#  '/teams/cle/2014.htm',
#  '/teams/oti/2014.htm',
#  '/teams/kan/2014.htm',
#  '/teams/nyj/2014.htm',
#  '/teams/rai/2014.htm',
#  '/teams/cin/2014.htm',
#  '/teams/rav/2014.htm',
#  '/teams/phi/2014.htm',
#  '/teams/jax/2014.htm',
#  '/teams/atl/2014.htm',
#  '/teams/nor/2014.htm',
#  '/teams/mia/2014.htm',
#  '/teams/nwe/2014.htm',
#  '/teams/htx/2014.htm',
#  '/teams/was/2014.htm',
#  '/teams/sfo/2014.htm',
#  '/teams/dal/2014.htm',
#  '/teams/car/2014.htm',
#  '/teams/tam/2014.htm',
#  '/teams/den/2014.htm',
#  '/teams/clt/2014.htm',
#  '/teams/det/2014.htm',
#  '/teams/nyg/2014.htm',
#  '/teams/crd/2014.htm',
#  '/teams/sdg/2014.htm',
#  '/teams/nwe/2015.htm',
#  '/teams/pit/2015.htm',
#  '/teams/ram/2015.htm',
#  '/teams/sea/2015.htm',
#  '/teams/gnb/2015.htm',
#  '/teams/chi/2015.htm',
#  '/teams/kan/2015.htm',
#  '/teams/htx/2015.htm',
#  '/teams/mia/2015.htm',
#  '/teams/was/2015.htm',
#  '/teams/buf/2015.htm',
#  '/teams/clt/2015.htm',
#  '/teams/car/2015.htm',
#  '/teams/jax/2015.htm',
#  '/teams/nyj/2015.htm',
#  '/teams/cle/2015.htm',
#  '/teams/crd/2015.htm',
#  '/teams/nor/2015.htm',
#  '/teams/sdg/2015.htm',
#  '/teams/det/2015.htm',
#  '/teams/den/2015.htm',
#  '/teams/rav/2015.htm',
#  '/teams/oti/2015.htm',
#  '/teams/tam/2015.htm',
#  '/teams/cin/2015.htm',
#  '/teams/rai/2015.htm',
#  '/teams/dal/2015.htm',
#  '/teams/nyg/2015.htm',
#  '/teams/atl/2015.htm',
#  '/teams/phi/2015.htm',
#  '/teams/sfo/2015.htm',
#  '/teams/min/2015.htm',
#  '/teams/den/2016.htm',
#  '/teams/car/2016.htm',
#  '/teams/gnb/2016.htm',
#  '/teams/jax/2016.htm',
#  '/teams/rav/2016.htm',
#  '/teams/buf/2016.htm',
#  '/teams/tam/2016.htm',
#  '/teams/atl/2016.htm',
#  '/teams/min/2016.htm',
#  '/teams/oti/2016.htm',
#  '/teams/rai/2016.htm',
#  '/teams/nor/2016.htm',
#  '/teams/phi/2016.htm',
#  '/teams/cle/2016.htm',
#  '/teams/kan/2016.htm',
#  '/teams/sdg/2016.htm',
#  '/teams/htx/2016.htm',
#  '/teams/chi/2016.htm',
#  '/teams/cin/2016.htm',
#  '/teams/nyj/2016.htm',
#  '/teams/sea/2016.htm',
#  '/teams/mia/2016.htm',
#  '/teams/nyg/2016.htm',
#  '/teams/dal/2016.htm',
#  '/teams/det/2016.htm',
#  '/teams/clt/2016.htm',
#  '/teams/nwe/2016.htm',
#  '/teams/crd/2016.htm',
#  '/teams/pit/2016.htm',
#  '/teams/was/2016.htm',
#  '/teams/sfo/2016.htm',
#  '/teams/ram/2016.htm',
#  '/teams/kan/2017.htm',
#  '/teams/nwe/2017.htm',
#  '/teams/atl/2017.htm',
#  '/teams/chi/2017.htm',
#  '/teams/buf/2017.htm',
#  '/teams/nyj/2017.htm',
#  '/teams/rai/2017.htm',
#  '/teams/oti/2017.htm',
#  '/teams/phi/2017.htm',
#  '/teams/was/2017.htm',
#  '/teams/rav/2017.htm',
#  '/teams/cin/2017.htm',
#  '/teams/pit/2017.htm',
#  '/teams/cle/2017.htm',
#  '/teams/det/2017.htm',
#  '/teams/crd/2017.htm',
#  '/teams/jax/2017.htm',
#  '/teams/htx/2017.htm',
#  '/teams/ram/2017.htm',
#  '/teams/clt/2017.htm',
#  '/teams/car/2017.htm',
#  '/teams/sfo/2017.htm',
#  '/teams/gnb/2017.htm',
#  '/teams/sea/2017.htm',
#  '/teams/dal/2017.htm',
#  '/teams/nyg/2017.htm',
#  '/teams/min/2017.htm',
#  '/teams/nor/2017.htm',
#  '/teams/den/2017.htm',
#  '/teams/sdg/2017.htm',
#  '/teams/htx/2017.htm',
#  '/teams/cin/2017.htm',
#  '/teams/phi/2018.htm',
#  '/teams/atl/2018.htm',
#  '/teams/tam/2018.htm',
#  '/teams/nor/2018.htm',
#  '/teams/rav/2018.htm',
#  '/teams/buf/2018.htm',
#  '/teams/cin/2018.htm',
#  '/teams/clt/2018.htm',
#  '/teams/pit/2018.htm',
#  '/teams/cle/2018.htm',
#  '/teams/mia/2018.htm',
#  '/teams/oti/2018.htm',
#  '/teams/nwe/2018.htm',
#  '/teams/htx/2018.htm',
#  '/teams/jax/2018.htm',
#  '/teams/nyg/2018.htm',
#  '/teams/min/2018.htm',
#  '/teams/sfo/2018.htm',
#  '/teams/kan/2018.htm',
#  '/teams/sdg/2018.htm',
#  '/teams/was/2018.htm',
#  '/teams/crd/2018.htm',
#  '/teams/car/2018.htm',
#  '/teams/dal/2018.htm',
#  '/teams/den/2018.htm',
#  '/teams/sea/2018.htm',
#  '/teams/gnb/2018.htm',
#  '/teams/chi/2018.htm',
#  '/teams/nyj/2018.htm',
#  '/teams/det/2018.htm',
#  '/teams/ram/2018.htm',
#  '/teams/rai/2018.htm',
#  '/teams/gnb/2019.htm',
#  '/teams/chi/2019.htm',
#  '/teams/min/2019.htm',
#  '/teams/atl/2019.htm',
#  '/teams/buf/2019.htm',
#  '/teams/nyj/2019.htm',
#  '/teams/phi/2019.htm',
#  '/teams/was/2019.htm',
#  '/teams/oti/2019.htm',
#  '/teams/cle/2019.htm',
#  '/teams/ram/2019.htm',
#  '/teams/car/2019.htm',
#  '/teams/kan/2019.htm',
#  '/teams/jax/2019.htm',
#  '/teams/rav/2019.htm',
#  '/teams/mia/2019.htm',
#  '/teams/sea/2019.htm',
#  '/teams/cin/2019.htm',
#  '/teams/sdg/2019.htm',
#  '/teams/clt/2019.htm',
#  '/teams/det/2019.htm',
#  '/teams/crd/2019.htm',
#  '/teams/dal/2019.htm',
#  '/teams/nyg/2019.htm',
#  '/teams/sfo/2019.htm',
#  '/teams/tam/2019.htm',
#  '/teams/nwe/2019.htm',
#  '/teams/pit/2019.htm',
#  '/teams/nor/2019.htm',
#  '/teams/htx/2019.htm',
#  '/teams/rai/2019.htm',
#  '/teams/den/2019.htm',
#  '/teams/kan/2020.htm',
#  '/teams/htx/2020.htm',
#  '/teams/sea/2020.htm',
#  '/teams/atl/2020.htm',
#  '/teams/buf/2020.htm',
#  '/teams/nyj/2020.htm',
#  '/teams/was/2020.htm',
#  '/teams/phi/2020.htm',
#  '/teams/gnb/2020.htm',
#  '/teams/min/2020.htm',
#  '/teams/rav/2020.htm',
#  '/teams/cle/2020.htm',
#  '/teams/nwe/2020.htm',
#  '/teams/mia/2020.htm',
#  '/teams/jax/2020.htm',
#  '/teams/clt/2020.htm',
#  '/teams/rai/2020.htm',
#  '/teams/car/2020.htm',
#  '/teams/chi/2020.htm',
#  '/teams/det/2020.htm',
#  '/teams/sdg/2020.htm',
#  '/teams/cin/2020.htm',
#  '/teams/nor/2020.htm',
#  '/teams/tam/2020.htm',
#  '/teams/crd/2020.htm',
#  '/teams/sfo/2020.htm',
#  '/teams/ram/2020.htm',
#  '/teams/dal/2020.htm',
#  '/teams/pit/2020.htm',
#  '/teams/nyg/2020.htm',
#  '/teams/oti/2020.htm',
#  '/teams/den/2020.htm']

# %%
# %%time
for seasonGameExt in seasonGameExts:
  # Request secondary page
  req2 = Request('https://www.pro-football-reference.com'+seasonGameExt)
  page2 = urlopen(req2).read()
  soup2 = BeautifulSoup(page2, 'html.parser')

  # Get season year and current team of interests name
  data_temp = soup2.find('div',attrs={'data-template':'Partials/Teams/Summary'}).find_all('span')
  gameYear = data_temp[0].getText()
  currentTeam_Name = data_temp[1].getText()

  # Contains all games for team and game stats
  table2 = soup2.find('div', attrs={'id':'all_games'}).find('tbody')
  
  # Get every row in the current table
  results2 = table2.find_all('tr')

  # Loop through each element in the row
  for result in results2:
    cols = result.find_all('td')
    gameDate = cols[1].getText()
    gameOutcome = cols[4].getText()
    team_record = cols[6].getText()
    opp_name = cols[8].getText()
    points_scored = cols[9].getText()
    points_opp = cols[10].getText()
    first_down = cols[11].getText()
    yards_off = cols[12].getText()
    pass_yds_off = cols[13].getText()
    rush_yds_off = cols[14].getText()
    to_off = cols[15].getText()
    first_down_def = cols[16].getText()
    yards_def = cols[17].getText()
    pass_def = cols[18].getText()
    rush_def = cols[19].getText()
    to_def = cols[20].getText()
    gameData.append([currentTeam_Name,gameYear,gameDate,gameOutcome,team_record,opp_name,points_scored,
                    points_opp,first_down,yards_off,pass_yds_off,rush_yds_off,to_off,first_down_def,
                    yards_def,pass_def,rush_def,to_def])
# Out:
# CPU times: user 19min 26s, sys: 4.87 s, total: 19min 31s
# Wall time: 24min 31s

# %%
# Print length of data
len(gameData[17:])
# Out:
# 6384

# %%
import pandas as pd 
gameData_df = pd.DataFrame(gameData[18:],columns=df_Cols)

# %%
# Show top and bottom of data 
display(gameData_df.head(10))
display(gameData_df.tail(10))
# Out:
#             team_name season_year  ... rush_yds_def to_def
# 0  New Orleans Saints        2010  ...           91      1
# 1  New Orleans Saints        2010  ...          142      4
# 2  New Orleans Saints        2010  ...          202      1
# 3  New Orleans Saints        2010  ...          118      1
# 4  New Orleans Saints        2010  ...           41      1
# 5  New Orleans Saints        2010  ...           42      1
# 6  New Orleans Saints        2010  ...          125
# 7  New Orleans Saints        2010  ...          108      2
# 8  New Orleans Saints        2010  ...          127      2
# 9  New Orleans Saints        2010  ...
#
# [10 rows x 18 columns]
#            team_name season_year    game_date  ... pass_yds_def rush_yds_def to_def
# 6373  Denver Broncos        2020   November 1  ...          275          210      2
# 6374  Denver Broncos        2020   November 8  ...          271           92      1
# 6375  Denver Broncos        2020  November 15  ...          154          203
# 6376  Denver Broncos        2020  November 22  ...          167           56      1
# 6377  Denver Broncos        2020  November 29  ...           63          229      1
# 6378  Denver Broncos        2020   December 6  ...          313          134
# 6379  Denver Broncos        2020  December 13  ...          245          125
# 6380  Denver Broncos        2020  December 19  ...          352          182      1
# 6381  Denver Broncos        2020  December 27  ...          227           89
# 6382  Denver Broncos        2020    January 3  ...          359          106      4
#
# [10 rows x 18 columns]

# %%
# Save df to csv
gameData_df.to_csv('Nfl_Game_Data_v2.csv')

# %%
len(gameData[18:])
# Out:
# 6383
